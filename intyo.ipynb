# %% [markdown]
# <a href="https://colab.research.google.com/github/ArkadiuszFedorowicz/BigDataProject/blob/main/intyo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# # Sformatowano jako kod
# ```
#
# # Import bibliotek

# %%
import numpy as np
import pandas as pd
import sklearn

sklearn.__version__
# Out:
# '0.22.2.post1'

# %% [markdown]
# # Dane

# %%
from google.colab import files 
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-23e305b1-e8d3-4b7a-904d-0b78b6797170" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-23e305b1-e8d3-4b7a-904d-0b78b6797170">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Seasons_Stats.csv to Seasons_Stats.csv

# %%
import pandas as pd 
import io 
  
df = pd.read_csv(io.BytesIO(uploaded['Seasons_Stats.csv'])) 
print(df)
# Out:
#        Unnamed: 0    Year             Player  Pos  ...   BLK   TOV     PF    PTS
# 0               0  1950.0    Curly Armstrong  G-F  ...   NaN   NaN  217.0  458.0
# 1               1  1950.0       Cliff Barker   SG  ...   NaN   NaN   99.0  279.0
# 2               2  1950.0      Leo Barnhorst   SF  ...   NaN   NaN  192.0  438.0
# 3               3  1950.0         Ed Bartels    F  ...   NaN   NaN   29.0   63.0
# 4               4  1950.0         Ed Bartels    F  ...   NaN   NaN   27.0   59.0
# ...           ...     ...                ...  ...  ...   ...   ...    ...    ...
# 24686       24686  2017.0        Cody Zeller   PF  ...  58.0  65.0  189.0  639.0
# 24687       24687  2017.0       Tyler Zeller    C  ...  21.0  20.0   61.0  178.0
# 24688       24688  2017.0  Stephen Zimmerman    C  ...   5.0   3.0   17.0   23.0
# 24689       24689  2017.0        Paul Zipser   SF  ...  16.0  40.0   78.0  240.0
# 24690       24690  2017.0        Ivica Zubac    C  ...  33.0  30.0   66.0  284.0
#
# ...

# %%
df.head(40)
# Out:
#     Unnamed: 0    Year            Player  Pos  ...  BLK TOV     PF     PTS
# 0            0  1950.0   Curly Armstrong  G-F  ...  NaN NaN  217.0   458.0
# 1            1  1950.0      Cliff Barker   SG  ...  NaN NaN   99.0   279.0
# 2            2  1950.0     Leo Barnhorst   SF  ...  NaN NaN  192.0   438.0
# 3            3  1950.0        Ed Bartels    F  ...  NaN NaN   29.0    63.0
# 4            4  1950.0        Ed Bartels    F  ...  NaN NaN   27.0    59.0
# 5            5  1950.0        Ed Bartels    F  ...  NaN NaN    2.0     4.0
# 6            6  1950.0       Ralph Beard    G  ...  NaN NaN  132.0   895.0
# 7            7  1950.0        Gene Berce  G-F  ...  NaN NaN    6.0    10.0
# 8            8  1950.0     Charlie Black  F-C  ...  NaN NaN  273.0   661.0
# 9            9  1950.0     Charlie Black  F-C  ...  NaN NaN  140.0   382.0
# 10          10  1950.0     Charlie Black  F-C  ...  NaN NaN  133.0   279.0
# ...

# %%
df_rawCopy = df

# %%
df_rawCopy.head(10)
# Out:
#    Unnamed: 0    Year           Player  Pos   Age  ... STL  BLK  TOV     PF    PTS
# 0           0  1950.0  Curly Armstrong  G-F  31.0  ... NaN  NaN  NaN  217.0  458.0
# 1           1  1950.0     Cliff Barker   SG  29.0  ... NaN  NaN  NaN   99.0  279.0
# 2           2  1950.0    Leo Barnhorst   SF  25.0  ... NaN  NaN  NaN  192.0  438.0
# 3           3  1950.0       Ed Bartels    F  24.0  ... NaN  NaN  NaN   29.0   63.0
# 4           4  1950.0       Ed Bartels    F  24.0  ... NaN  NaN  NaN   27.0   59.0
# 5           5  1950.0       Ed Bartels    F  24.0  ... NaN  NaN  NaN    2.0    4.0
# 6           6  1950.0      Ralph Beard    G  22.0  ... NaN  NaN  NaN  132.0  895.0
# 7           7  1950.0       Gene Berce  G-F  23.0  ... NaN  NaN  NaN    6.0   10.0
# 8           8  1950.0    Charlie Black  F-C  28.0  ... NaN  NaN  NaN  273.0  661.0
# 9           9  1950.0    Charlie Black  F-C  28.0  ... NaN  NaN  NaN  140.0  382.0
#
# [10 rows x 53 columns]

# %%
df_rawCopy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24691 entries, 0 to 24690
# Data columns (total 53 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  24691 non-null  int64
#  1   Year        24624 non-null  float64
#  2   Player      24624 non-null  object
#  3   Pos         24624 non-null  object
#  4   Age         24616 non-null  float64
#  5   Tm          24624 non-null  object
#  6   G           24624 non-null  float64
#  7   GS          18233 non-null  float64
#  8   MP          24138 non-null  float64
#  9   PER         24101 non-null  float64
#  10  TS%         24538 non-null  float64
#  11  3PAr        18839 non-null  float64
#  12  FTr         24525 non-null  float64
#  13  ORB%        20792 non-null  float64
#  14  DRB%        20792 non-null  float64
#  15  TRB%        21571 non-null  float64
#  16  AST%        22555 non-null  float64
#  17  STL%        20792 non-null  float64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0          Year  ...            PF           PTS
# count  24691.000000  24624.000000  ...  24624.000000  24624.000000
# mean   12345.000000   1992.594989  ...    116.339222    510.116350
# std     7127.822084     17.429594  ...     84.791873    492.922981
# min        0.000000   1950.000000  ...      0.000000      0.000000
# 25%     6172.500000   1981.000000  ...     39.000000    106.000000
# 50%    12345.000000   1996.000000  ...    109.000000    364.000000
# 75%    18517.500000   2007.000000  ...    182.000000    778.000000
# max    24690.000000   2017.000000  ...    386.000000   4029.000000
#
# [8 rows x 50 columns]

# %%
df.describe().T
# Out:
#               count          mean          std  ...        50%        75%        max
# Unnamed: 0  24691.0  12345.000000  7127.822084  ...  12345.000  18517.500  24690.000
# Year        24624.0   1992.594989    17.429594  ...   1996.000   2007.000   2017.000
# Age         24616.0     26.664405     3.841892  ...     26.000     29.000     44.000
# G           24624.0     50.837110    26.496161  ...     58.000     75.000     88.000
# GS          18233.0     23.593375    28.632387  ...      8.000     45.000     83.000
# MP          24138.0   1209.720317   941.146575  ...   1053.000   1971.000   3882.000
# PER         24101.0     12.479071     6.039014  ...     12.700     15.600    129.100
# TS%         24538.0      0.493001     0.094469  ...      0.506      0.544      1.136
# 3PAr        18839.0      0.158604     0.187495  ...      0.064      0.288      1.000
# FTr         24525.0      0.325455     0.218971  ...      0.296      0.400      6.000
# ...

# %%
for col in ['Pos',]:
    df[col] = df[col].astype('category')



df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24691 entries, 0 to 24690
# Data columns (total 53 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  24691 non-null  int64
#  1   Year        24624 non-null  float64
#  2   Player      24624 non-null  object
#  3   Pos         24624 non-null  category
#  4   Age         24616 non-null  float64
#  5   Tm          24624 non-null  object
#  6   G           24624 non-null  float64
#  7   GS          18233 non-null  float64
#  8   MP          24138 non-null  float64
#  9   PER         24101 non-null  float64
#  10  TS%         24538 non-null  float64
#  11  3PAr        18839 non-null  float64
#  12  FTr         24525 non-null  float64
#  13  ORB%        20792 non-null  float64
#  14  DRB%        20792 non-null  float64
#  15  TRB%        21571 non-null  float64
#  16  AST%        22555 non-null  float64
#  17  STL%        20792 non-null  float64
# ...

# %%
df.describe(include=['category']).T
# Out:
#      count unique top  freq
# Pos  24624     23  PF  4966

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# Year             67
# Player           67
# Pos              67
# Age              75
# Tm               67
# G                67
# GS             6458
# MP              553
# PER             590
# TS%             153
# 3PAr           5852
# FTr             166
# ORB%           3899
# DRB%           3899
# TRB%           3120
# AST%           2136
# STL%           3899
# BLK%           3899
# TOV%           5109
# USG%           5051
# blanl         24691
# OWS             106
# DWS             106
# WS              106
# WS/48           590
# blank2        24691
# OBPM           3894
# DBPM           3894
# BPM            3894
# VORP           3894
# FG               67
# FGA              67
# FG%             166
# 3P             5764
# 3PA            5764
# 3P%            9275
# 2P               67
# 2PA              67
# 2P%             195
# eFG%            166
# FT               67
# FTA              67
# FT%             925
# ORB            3894
# ...

# %%
from sklearn.impute import SimpleImputer

# strategy: 'mean', 'median', 'most_frequent', 'constant'
imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imputer.fit(df[['Pos']])
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='most_frequent', verbose=0)

# %%
for col in ['Pos']:
    df[col] = df[col].astype('category')


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24691 entries, 0 to 24690
# Data columns (total 53 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  24691 non-null  int64
#  1   Year        24624 non-null  float64
#  2   Player      24624 non-null  object
#  3   Pos         24624 non-null  category
#  4   Age         24616 non-null  float64
#  5   Tm          24624 non-null  object
#  6   G           24624 non-null  float64
#  7   GS          18233 non-null  float64
#  8   MP          24138 non-null  float64
#  9   PER         24101 non-null  float64
#  10  TS%         24538 non-null  float64
#  11  3PAr        18839 non-null  float64
#  12  FTr         24525 non-null  float64
#  13  ORB%        20792 non-null  float64
#  14  DRB%        20792 non-null  float64
#  15  TRB%        21571 non-null  float64
#  16  AST%        22555 non-null  float64
#  17  STL%        20792 non-null  float64
# ...

# %%
df.describe().T
# Out:
#               count          mean          std  ...        50%        75%        max
# Unnamed: 0  24691.0  12345.000000  7127.822084  ...  12345.000  18517.500  24690.000
# Year        24624.0   1992.594989    17.429594  ...   1996.000   2007.000   2017.000
# Age         24616.0     26.664405     3.841892  ...     26.000     29.000     44.000
# G           24624.0     50.837110    26.496161  ...     58.000     75.000     88.000
# GS          18233.0     23.593375    28.632387  ...      8.000     45.000     83.000
# MP          24138.0   1209.720317   941.146575  ...   1053.000   1971.000   3882.000
# PER         24101.0     12.479071     6.039014  ...     12.700     15.600    129.100
# TS%         24538.0      0.493001     0.094469  ...      0.506      0.544      1.136
# 3PAr        18839.0      0.158604     0.187495  ...      0.064      0.288      1.000
# FTr         24525.0      0.325455     0.218971  ...      0.296      0.400      6.000
# ...

# %%
df
# Out:
#        Unnamed: 0    Year             Player  Pos  ...   BLK   TOV     PF    PTS
# 0               0  1950.0    Curly Armstrong  G-F  ...   NaN   NaN  217.0  458.0
# 1               1  1950.0       Cliff Barker   SG  ...   NaN   NaN   99.0  279.0
# 2               2  1950.0      Leo Barnhorst   SF  ...   NaN   NaN  192.0  438.0
# 3               3  1950.0         Ed Bartels    F  ...   NaN   NaN   29.0   63.0
# 4               4  1950.0         Ed Bartels    F  ...   NaN   NaN   27.0   59.0
# ...           ...     ...                ...  ...  ...   ...   ...    ...    ...
# 24686       24686  2017.0        Cody Zeller   PF  ...  58.0  65.0  189.0  639.0
# 24687       24687  2017.0       Tyler Zeller    C  ...  21.0  20.0   61.0  178.0
# 24688       24688  2017.0  Stephen Zimmerman    C  ...   5.0   3.0   17.0   23.0
# 24689       24689  2017.0        Paul Zipser   SF  ...  16.0  40.0   78.0  240.0
# 24690       24690  2017.0        Ivica Zubac    C  ...  33.0  30.0   66.0  284.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# Year             67
# Player           67
# Pos              67
# Age              75
# Tm               67
# G                67
# GS             6458
# MP              553
# PER             590
# TS%             153
# 3PAr           5852
# FTr             166
# ORB%           3899
# DRB%           3899
# TRB%           3120
# AST%           2136
# STL%           3899
# BLK%           3899
# TOV%           5109
# USG%           5051
# blanl         24691
# OWS             106
# DWS             106
# WS              106
# WS/48           590
# blank2        24691
# OBPM           3894
# DBPM           3894
# BPM            3894
# VORP           3894
# FG               67
# FGA              67
# FG%             166
# 3P             5764
# 3PA            5764
# 3P%            9275
# 2P               67
# 2PA              67
# 2P%             195
# eFG%            166
# FT               67
# FTA              67
# FT%             925
# ORB            3894
# ...

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value='G-F')
imputer.fit_transform(df[['Pos']])
# Out:
# array([['G-F'],
#        ['SG'],
#        ['SF'],
#        ...,
#        ['C'],
#        ['SF'],
#        ['C']], dtype=object)

# %%
df['Pos'].fillna(value='G-F', inplace=True)
df
# Out:
#        Unnamed: 0    Year             Player  Pos  ...   BLK   TOV     PF    PTS
# 0               0  1950.0    Curly Armstrong  G-F  ...   NaN   NaN  217.0  458.0
# 1               1  1950.0       Cliff Barker   SG  ...   NaN   NaN   99.0  279.0
# 2               2  1950.0      Leo Barnhorst   SF  ...   NaN   NaN  192.0  438.0
# 3               3  1950.0         Ed Bartels    F  ...   NaN   NaN   29.0   63.0
# 4               4  1950.0         Ed Bartels    F  ...   NaN   NaN   27.0   59.0
# ...           ...     ...                ...  ...  ...   ...   ...    ...    ...
# 24686       24686  2017.0        Cody Zeller   PF  ...  58.0  65.0  189.0  639.0
# 24687       24687  2017.0       Tyler Zeller    C  ...  21.0  20.0   61.0  178.0
# 24688       24688  2017.0  Stephen Zimmerman    C  ...   5.0   3.0   17.0   23.0
# 24689       24689  2017.0        Paul Zipser   SF  ...  16.0  40.0   78.0  240.0
# 24690       24690  2017.0        Ivica Zubac    C  ...  33.0  30.0   66.0  284.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# Year             67
# Player           67
# Pos               0
# Age              75
# Tm               67
# G                67
# GS             6458
# MP              553
# PER             590
# TS%             153
# 3PAr           5852
# FTr             166
# ORB%           3899
# DRB%           3899
# TRB%           3120
# AST%           2136
# STL%           3899
# BLK%           3899
# TOV%           5109
# USG%           5051
# blanl         24691
# OWS             106
# DWS             106
# WS              106
# WS/48           590
# blank2        24691
# OBPM           3894
# DBPM           3894
# BPM            3894
# VORP           3894
# FG               67
# FGA              67
# FG%             166
# 3P             5764
# 3PA            5764
# 3P%            9275
# 2P               67
# 2PA              67
# 2P%             195
# eFG%            166
# FT               67
# FTA              67
# FT%             925
# ORB            3894
# ...

# %%
data_blank = df.copy()
data_ready = data_blank.pop('blank2')

# %%
df
# Out:
#        Unnamed: 0    Year             Player  Pos  ...   BLK   TOV     PF    PTS
# 0               0  1950.0    Curly Armstrong  G-F  ...   NaN   NaN  217.0  458.0
# 1               1  1950.0       Cliff Barker   SG  ...   NaN   NaN   99.0  279.0
# 2               2  1950.0      Leo Barnhorst   SF  ...   NaN   NaN  192.0  438.0
# 3               3  1950.0         Ed Bartels    F  ...   NaN   NaN   29.0   63.0
# 4               4  1950.0         Ed Bartels    F  ...   NaN   NaN   27.0   59.0
# ...           ...     ...                ...  ...  ...   ...   ...    ...    ...
# 24686       24686  2017.0        Cody Zeller   PF  ...  58.0  65.0  189.0  639.0
# 24687       24687  2017.0       Tyler Zeller    C  ...  21.0  20.0   61.0  178.0
# 24688       24688  2017.0  Stephen Zimmerman    C  ...   5.0   3.0   17.0   23.0
# 24689       24689  2017.0        Paul Zipser   SF  ...  16.0  40.0   78.0  240.0
# 24690       24690  2017.0        Ivica Zubac    C  ...  33.0  30.0   66.0  284.0
#
# ...

# %%
data_row = df.copy()

# %%
del df['blank2']

# %%
del df['blanl']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24691 entries, 0 to 24690
# Data columns (total 51 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  24691 non-null  int64
#  1   Year        24624 non-null  float64
#  2   Player      24624 non-null  object
#  3   Pos         24691 non-null  category
#  4   Age         24616 non-null  float64
#  5   Tm          24624 non-null  object
#  6   G           24624 non-null  float64
#  7   GS          18233 non-null  float64
#  8   MP          24138 non-null  float64
#  9   PER         24101 non-null  float64
#  10  TS%         24538 non-null  float64
#  11  3PAr        18839 non-null  float64
#  12  FTr         24525 non-null  float64
#  13  ORB%        20792 non-null  float64
#  14  DRB%        20792 non-null  float64
#  15  TRB%        21571 non-null  float64
#  16  AST%        22555 non-null  float64
#  17  STL%        20792 non-null  float64
# ...
